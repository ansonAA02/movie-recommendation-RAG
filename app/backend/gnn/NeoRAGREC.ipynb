# %%
import os
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'
import torch
print(torch.__version__)

# 安裝匹配 PyTorch 的 PyG extension wheels（torch 2.8.0+cu126）
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-2.8.0+cu126.html
# !pip install -q torch-sparse  -f https://data.pyg.org/whl/torch-2.8.0+cu126.html
# !pip install -q torch-cluster -f https://data.pyg.org/whl/torch-2.8.0+cu126.html
# !pip install -q torch-spline-conv -f https://data.pyg.org/whl/torch-2.8.0+cu126.html

# 最後安裝 torch-geometric meta package
# !pip install -q torch-geometric
# !pip install -q neo4j faiss-cpu sentence-transformers tqdm
# Out:
# 2.10.0+cu128
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 45.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 141.1 MB/s eta 0:00:00

# %%
# 只在需要時執行一次即可
try:
    from torch.serialization import add_safe_globals
    from torch_geometric.data.storage import BaseStorage
    add_safe_globals([BaseStorage])
    print("Added BaseStorage to safe globals.")
except Exception as e:
    print("Could not add safe globals (maybe older torch) :", e)

# %%
import importlib, sys
try:
    import torch_geometric
    print("torch_geometric:", torch_geometric.__version__)
except Exception as e:
    print("torch_geometric import error:", e)

# 檢查各擴展
for mod in ["torch_scatter", "torch_sparse", "torch_cluster", "torch_spline_conv"]:
    try:
        importlib.import_module(mod)
        print(mod, "OK")
    except Exception as e:
        print(mod, "ERROR:", e)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 安裝 PyTorch (Colab 自帶 GPU 版)
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))

# 安裝 PyTorch Geometric（和你本地相容）
# !pip install torch-scatter torch-sparse torch-geometric -f https://data.pyg.org/whl/torch-2.3.0+cu121.html

# 安裝 Neo4j 驅動
# !pip install neo4j

# 安裝 FAISS（CPU 版即可，Colab 也不能用 GPU 版）
# !pip install faiss-cpu
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-80GB
# Looking in links: https://data.pyg.org/whl/torch-2.3.0+cu121.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 106.9 MB/s eta 0:00:00
# ...

# %%
# %cd "/content/drive/MyDrive/MyDrive/fyp_gnn"
# !ls -la "/content/drive/MyDrive/MyDrive/fyp_gnn"
# Out:
# /content/drive/MyDrive/MyDrive/fyp_gnn
# total 223185
# -rw------- 1 root root 203035153 Mar 30 03:54 data_kg.pt
# -rw------- 1 root root      9511 Nov 21 08:22 dataset.py
# -rw------- 1 root root     12983 Nov 21 15:58 export_kg_to_pyg.py
# -rw------- 1 root root  11928621 Mar 26 03:00 faiss.index
# -rw------- 1 root root       119 Mar 19 12:21 hybrid_ltr_weights.json
# -rw------- 1 root root    158727 Mar 26 03:00 id_map.json
# -rw------- 1 root root         0 Mar 26 06:09 __init__.py
# -rw------- 1 root root   1376272 Mar 26 03:00 meta.json
# -rw------- 1 root root     12635 Nov 21 15:58 model.py
# -rw------- 1 root root  11928704 Mar 26 03:00 movie_embeddings.npy
# -rw------- 1 root root     57831 Mar 30 03:54 movie_id_map.json
# drwx------ 2 root root      4096 Nov 21 14:49 output
# drwx------ 2 root root      4096 Nov 21 14:49 __pycache__
# -rw------- 1 root root      8587 Jan  7 15:56 train_gnn.py

# %%
# %cd /content/drive/MyDrive/MyDrive

# 如果沒有 __init__.py，建立一個
# !mkdir -p fyp_gnn
# !touch fyp_gnn/__init__.py
# !ls -R fyp_gnn



# %cd /content/drive/MyDrive/MyDrive
# !echo "TRAIN START"

# !python -m fyp_gnn.train_gnn \
  --data-path "/content/drive/MyDrive/MyDrive/fyp_gnn/data_kg.pt" \
  --movie-id-map "/content/drive/MyDrive/MyDrive/fyp_gnn/movie_id_map.json" \
  --output-dir "/content/drive/MyDrive/MyDrive/fyp_gnn/output" \
  --epochs 50 \
  --batch-size 8 \
  --hidden-dim 128 \
  --out-dim 256 \
  --num-gnn-layers 2 \
  --num-attn-layers 1 \
  --lr 1e-3 \
  --temperature 0.2 \
  --device cuda
# Out:
# /content/drive/MyDrive/MyDrive
# fyp_gnn:
# data_kg.pt		 id_map.json	       movie_id_map.json
# dataset.py		 __init__.py	       output
# export_kg_to_pyg.py	 meta.json	       __pycache__
# faiss.index		 model.py	       train_gnn.py
# hybrid_ltr_weights.json  movie_embeddings.npy
#
# fyp_gnn/output:
# movie_subgraph_embeddings.npy  train_lightgcn_colab.ipynb
# movie_subgraph_id_map.json
#
# fyp_gnn/__pycache__:
# dataset.cpython-312.pyc   model.cpython-312.pyc
# __init__.cpython-312.pyc  train_gnn.cpython-312.pyc
# /content/drive/MyDrive/MyDrive
# TRAIN START
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cuda.so
#   import torch_geometric.typing
# ...
